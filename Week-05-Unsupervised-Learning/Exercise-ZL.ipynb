# %% [markdown]
# # Fall 2024 Data Science Track: Week 5 - Unsupervised Learning

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need: `matplotlib`, `networkx`, `numpy`, and `pandas`―and also `ast.literal_eval` to correctly deserialize two columns in the `rules.tsv.xz` file.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Don’t worry about this. This is needed to interpret the Python code that is embedded in the data set. You only need it literally in the very next code cell and nowhere else. 
from ast import literal_eval

# The rest is just the stuff from the lecture.
from matplotlib import pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd

# %% [markdown]
# # Instacart Association Rules

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the Instacart association rules data set, mined from the [Instacart Market Basket Analysis data set](https://www.kaggle.com/c/instacart-market-basket-analysis/data) on Kaggle. [The script](https://github.com/LiKenun/shopping-assistant/blob/main/api/preprocess_instacart_market_basket_analysis_data.py) that does it and the instructions to run it can be found in my [Shopping Assistant Project](https://github.com/LiKenun/shopping-assistant) repository.

# %% [markdown]
# ## Load the Data
#
# This code has already been pre-written, simply because there are a few quirks which require converters to ensure the correct deserialization of some columns.

# %%
rules_data_path = 'data/rules.tsv.xz'                       # You do not need to decompress this yourself. Pandas understands how to read compressed data.

df_rules = pd.read_csv(rules_data_path,
                       sep='\t',
                       quoting=3,                           # This disables interpretation of quotes by Pandas itself, because both single and double quotes will be resolved by literal_eval.
                       converters={
                           'consequent_item': literal_eval,
                           'antecedent_items': literal_eval # This reads something like ["Grandma's 8\" Chip Cookies", '6" Apple Pie'] into a list, so you will get a column where each individual cell is a list.
                       },
                       low_memory=True)                     # For Chris
# Out:
# <unknown>:1: SyntaxWarning: invalid escape sequence '\G'

# %% [markdown]
# But just *how* many rules were just loaded‽

# %%
# Show the list of column names and the number of rules.


print(df_rules.columns)

print(f"Number of rules: {len(df_rules)}")
# Out:
# Index(['consequent_item', 'transaction_count', 'item_set_count',
#        'antecedent_count', 'consequent_count', 'antecedent_items'],
#       dtype='object')
# Number of rules: 1048575

# %% [markdown]
# ## Metrics
#
# Compute the support, confidence, and lift of each rule.
#
# * The rule’s *support* tells you how frequently the set of items appears in the dataset. It’s important to prune infrequent sets from further consideration.
#     * The simple definition: $$P(A \cap B)$$
#     * `= item_set_count / transaction_count`
# * The rule’s *confidence* tells you how often a the rule is true. Divide the support for the set of items by the support for just the antecedents. Rules which are not true very often are also pruned.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count)`
#     * `= item_set_count / antecedent_count`
# * The rule’s *lift* tells you how much more likely the consequent is, given the antecedents, compared to its baseline probability. Divide the support for the set of items by both the support of the antecedents and consequent. Equivalently, divide the confidence by the support of the consequent.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A) \cdot P(B)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count * (consequent_count / transaction_count))`
#     * `= item_set_count / antecedent_count / (consequent_count / transaction_count)`
#     * `= item_set_count * transaction_count / (antecedent_count * consequent_count)`

# %%
# Add new columns support, confidence, and lift to df_rules. And show the first 50 rules.
#print(df_rules.columns)

#df_rules = # Something goes here.
transaction_count = len(df_rules)


df_rules['support'] = df_rules['item_set_count'] / transaction_count
df_rules['confidence'] = df_rules['item_set_count'] / df_rules['antecedent_count']
df_rules['lift'] = (df_rules['item_set_count'] * transaction_count) / (df_rules['antecedent_count'] * df_rules['consequent_count'])

df_rules.head(50)
# Out:
#                                       consequent_item  transaction_count  \
# 0   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 1   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 2    Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 3                           Total 0% Raspberry Yogurt            3346083
# 4                                 Pineapple Yogurt 2%            3346083
# 5                          Fat Free Strawberry Yogurt            3346083
# 6                           Fat Free Blueberry Yogurt            3346083
# 7   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 8   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 9   Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 10  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 11                          Total 0% Raspberry Yogurt            3346083
# 12                                Pineapple Yogurt 2%            3346083
# 13                         Fat Free Strawberry Yogurt            3346083
# 14                                  Blackberry Yogurt            3346083
# 15  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 16  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 17   Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 18                          Total 0% Raspberry Yogurt            3346083
# 19                                Pineapple Yogurt 2%            3346083
# 20                         Fat Free Strawberry Yogurt            3346083
# 21                          Fat Free Blueberry Yogurt            3346083
# 22  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 23  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 24  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 25  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 26                          Total 0% Raspberry Yogurt            3346083
# 27                                Pineapple Yogurt 2%            3346083
# 28                         Fat Free Strawberry Yogurt            3346083
# 29                                  Blackberry Yogurt            3346083
# 30  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 31  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 32   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 33  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 34  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 35  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 36                          Total 0% Raspberry Yogurt            3346083
# 37                         Fat Free Strawberry Yogurt            3346083
# 38                                  Blackberry Yogurt            3346083
# 39  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 40  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 41   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 42  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 43  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 44  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 45                          Total 0% Raspberry Yogurt            3346083
# 46                         Fat Free Strawberry Yogurt            3346083
# 47                                  Blackberry Yogurt            3346083
# 48  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 49  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
#
#     item_set_count  antecedent_count  consequent_count  \
# 0              101               123               128
# 1              101               128               123
# 2              101               123               128
# 3              101               123               128
# 4              101               128               123
# 5              101               123               128
# 6              101               128               123
# 7              101               147               117
# 8              101               147               117
# 9              101               117               147
# 10             101               117               147
# 11             101               147               117
# 12             101               147               117
# 13             101               117               147
# 14             101               117               147
# 15             101               119               145
# 16             101               145               119
# 17             101               119               145
# 18             101               145               119
# 19             101               145               119
# 20             101               119               145
# 21             101               145               119
# 22             101               132               133
# 23             101               132               133
# 24             101               133               132
# 25             101               132               133
# 26             101               133               132
# 27             101               133               132
# 28             101               132               133
# 29             101               133               132
# 30             103               129               139
# 31             103               139               129
# 32             103               139               129
# 33             103               139               129
# 34             103               129               139
# 35             103               139               129
# 36             103               139               129
# 37             103               129               139
# 38             103               129               139
# 39             103               144               125
# 40             103               144               125
# 41             103               125               144
# 42             103               144               125
# 43             103               125               144
# 44             103               144               125
# 45             103               144               125
# 46             103               125               144
# 47             103               125               144
# 48             102               123               145
# 49             102               145               123
#
#                                      antecedent_items   support  \
# 0   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000096
# 1   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000096
# 2   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000096
# 3   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000096
# 4   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000096
# 5   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000096
# 6   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000096
# 7   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000096
# 8   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000096
# 9   [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000096
# 10  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000096
# 11  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000096
# 12  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000096
# 13  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000096
# 14  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000096
# 15  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000096
# 16  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000096
# 17  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000096
# 18  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000096
# 19  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000096
# 20  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000096
# 21  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000096
# 22  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000096
# 23  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000096
# 24  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000096
# 25  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000096
# 26  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000096
# 27  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000096
# 28  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000096
# 29  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000096
# 30  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 31  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 32  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 33  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 34  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 35  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 36  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 37  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 38  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 39  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 40  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 41  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 42  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 43  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 44  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 45  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000098
# 46  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 47  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000098
# 48  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000097
# 49  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000097
#
#     antecedent_item_count  confidence         lift
# 0                       3    0.821138  6726.757812
# 1                       4    0.789062  6726.757812
# 2                       3    0.821138  6726.757812
# 3                       3    0.821138  6726.757812
# 4                       4    0.789062  6726.757812
# 5                       3    0.821138  6726.757812
# 6                       4    0.789062  6726.757812
# 7                       4    0.687075  6157.687947
# 8                       4    0.687075  6157.687947
# 9                       4    0.863248  6157.687947
# 10                      4    0.863248  6157.687947
# 11                      4    0.687075  6157.687947
# 12                      4    0.687075  6157.687947
# 13                      4    0.863248  6157.687947
# 14                      4    0.863248  6157.687947
# 15                      4    0.848739  6137.703564
# 16                      3    0.696552  6137.703564
# 17                      4    0.848739  6137.703564
# 18                      3    0.696552  6137.703564
# 19                      3    0.696552  6137.703564
# 20                      4    0.848739  6137.703564
# 21                      3    0.696552  6137.703564
# 22                      4    0.765152  6032.471805
# 23                      4    0.765152  6032.471805
# 24                      4    0.759398  6032.471805
# 25                      4    0.765152  6032.471805
# 26                      4    0.759398  6032.471805
# 27                      4    0.759398  6032.471805
# 28                      4    0.765152  6032.471805
# 29                      4    0.759398  6032.471805
# 30                      5    0.798450  6023.268362
# 31                      4    0.741007  6023.268362
# 32                      4    0.741007  6023.268362
# 33                      4    0.741007  6023.268362
# 34                      5    0.798450  6023.268362
# 35                      4    0.741007  6023.268362
# 36                      4    0.741007  6023.268362
# 37                      5    0.798450  6023.268362
# 38                      5    0.798450  6023.268362
# 39                      4    0.715278  6000.179167
# 40                      4    0.715278  6000.179167
# 41                      5    0.824000  6000.179167
# 42                      4    0.715278  6000.179167
# 43                      5    0.824000  6000.179167
# 44                      4    0.715278  6000.179167
# 45                      4    0.715278  6000.179167
# 46                      5    0.824000  6000.179167
# 47                      5    0.824000  6000.179167
# 48                      3    0.829268  5996.896552
# 49                      3    0.703448  5996.896552

# %% [markdown]
# The yogurts have got some insane lift (*over 9,000*). Why do you think that might be?

# %% [markdown]
# antecendt items and consequent item just talking about yogurts*(Write your answer here.)*

# %%
# Query the rule set if you have to to find out more.
#just talking about yogurts

# %% [markdown]
# ## Network Visualization for Consequents with Single Antecedents
#
# Let’s now visualize a small subset of 1,000,000+ rules. First, filter the rule set for the following to whittle it down to something more manageable:
#
# 1. The rule must have exactly `1` antecedent item. (There should be 38,684 such rules.)
# 2. The lift must be between `5` and `20`. (There should be 1,596 such rules, including the prior criterion.)
# 3. Either the antecedent or consequent of the rule must contain `'Hummus'`, but not both. (This should get you down to 26 rules.)
#     * Convert the antecedents `list`-typed column to a `str`-typed column (`antecedent_item`) since there will only be a single antecedent in the subset.
#     * Replace any item containing `'Hummus'` to just `'Hummus'`. This will make the visualization more readable later.
#
# Hint: your code may run more efficiently if you re-order certain processing steps.
#
# Assign the subset to `df_rules_subset`.

# %%
# Define df_rules_subset.

filtered_rules = df_rules[(df_rules['antecedent_count'] == 1) &
                          (df_rules['lift'] > 5) & (df_rules['lift'] < 20)]
hummus_rules = filtered_rules[((filtered_rules['antecedent_items'].apply(lambda x: 'Hummus' in x)) &
                               ~filtered_rules['consequent_item'].apply(lambda x: 'Hummus' in x)) |
                              (~filtered_rules['antecedent_items'].apply(lambda x: 'Hummus' in x) &
                               filtered_rules['consequent_item'].apply(lambda x: 'Hummus' in x))]

hummus_rules['antecedent_item'] = hummus_rules['antecedent_items'].apply(lambda x: 'Hummus' if 'Hummus' in x else x[0])

# Assign to df_rules_subset
df_rules_subset = hummus_rules[['antecedent_items', 'consequent_item', 'support', 'confidence', 'lift']]

# %% [markdown]
# Build a network `graph_rules_subset` from the association rules subset.

# %%
graph_rules_subset = nx.MultiDiGraph()

edges = [(row['antecedent_items'], row['consequent_item']) for _, row in df_rules_subset.iterrows() if row['consequent_item']]
graph_rules_subset.add_edges_from(edges)

plt.figure(figsize=(15, 10))
pos = nx.spring_layout(graph_rules_subset)
nx.draw_networkx_nodes(graph_rules_subset, pos, node_size=300, node_color='lightblue')
nx.draw_networkx_edges(graph_rules_subset, pos, arrowstyle='-|>', arrowsize=10)
nx.draw_networkx_labels(graph_rules_subset, pos, font_size=8)

plt.title("Network Visualization of Association Rules Subset")
plt.axis('off')
#plt.show()
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# What can you tell about people who buy hummus?

# %% [markdown]
# not sure bec having issues with the graph *(Write your answer here.)*

# %% [markdown]
# ## Make a Prediction
#
# Given that the basket of items contains the following items, use the full set of association rules to predict the next 20 most likely items (consequents) that the person will add to the basket in descending order of lift:
#
# * `'Orange Bell Pepper'`
# * `'Organic Red Bell Pepper'`
#
# Hint: a single item in the basket may be a better predictor of some consequents than both items considered together. You must consider both or either, but not neither.

# %%
# Given basket of items
basket = {'Orange Bell Pepper', 'Organic Red Bell Pepper'}

# Predict the next 20 most likely items
predictions = df_rules[
    (df_rules['antecedent_items'].apply(lambda x: any(item in x for item in basket)))  # Match if any item in basket
].sort_values('lift', ascending=False).head(20)

print(predictions[['consequent_item', 'lift']])
# Out:
#                                           consequent_item       lift
# 342462      Icelandic Style Skyr Blueberry Non-fat Yogurt  25.133280
# 345882      Icelandic Style Skyr Blueberry Non-fat Yogurt  22.295078
# 346832           Nonfat Icelandic Style Strawberry Yogurt  21.566631
# 346901                           Non Fat Raspberry Yogurt  21.513699
# 349532      Icelandic Style Skyr Blueberry Non-fat Yogurt  19.565291
# 350852      Icelandic Style Skyr Blueberry Non-fat Yogurt  18.624774
# 350991                           Non Fat Raspberry Yogurt  18.513489
# 351360      Icelandic Style Skyr Blueberry Non-fat Yogurt  18.231560
# 351433           Nonfat Icelandic Style Strawberry Yogurt  18.158777
# 351881      Icelandic Style Skyr Blueberry Non-fat Yogurt  17.822188
# 352283                         Vanilla Skyr Nonfat Yogurt  17.515457
# 352884                        Organic Frozen Mango Chunks  17.074054
# 353323                         Vanilla Skyr Nonfat Yogurt  16.732997
# 353543                         Organic Orange Bell Pepper  16.565761
# 353580                           Non Fat Raspberry Yogurt  16.546364
# 353760                             Organic Sliced Peaches  16.415045
# 354421  Total 2% with Strawberry Lowfat Greek Strained...  15.903155
# 355427                                Organic Bell Pepper  15.163497
# 355819                                Organic Bell Pepper  14.878469
# 356261                                 Yellow Bell Pepper  14.551721

# %% [markdown]
# ## Bonus: Other Interesting Findings
#
# Find and share something else interesting about these association rules. It can be a graph, table, or some other format that illustrates your point.
